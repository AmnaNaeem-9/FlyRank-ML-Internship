# %% [markdown]
# <a href="https://colab.research.google.com/github/AmnaNaeem-9/FlyRank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AmnaNaeem-9/FlyRank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# I am choosing the Growth / Recovery / Momentum Prediction direction. I chose this lane because I want to investigate whether the historical performance of a content page can provide useful information about what may happen to that page in the future. Instead of only describing which pages are currently performing well or poorly, this project focuses on making a future-oriented prediction. The dataset contains historical search and engagement signals such as impressions, clicks, sessions, CTR, average position, content age, and recent trends, which gives me a reasonable starting point for testing whether these signals can help predict future page movement. I also think this direction is suitable for an ML capstone because it requires feature engineering, supervised learning, proper time-based validation, and careful leakage checking.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ## 2. The question: decision, action, cost of a wrong call

# My main decision is to identify which content pages are more likely to experience a future decline, recovery, or positive momentum so that they can be prioritized for review. The main user of this prediction would be a content or SEO reviewer who has limited time and cannot manually investigate every page. My model would therefore act as a decision-support tool rather than an automatic decision maker. A high-risk or high-opportunity prediction could help a reviewer decide which pages should be examined first.

# A wrong prediction can have different costs. A false positive could cause the reviewer to spend time investigating a page that would have remained healthy, while a false negative could cause a page with genuine future problems to be overlooked. Because of this, I will need to evaluate the model using metrics that reflect the actual ranking decision and not rely only on general accuracy. I will also need to consider the trade-off between finding important pages and creating too many unnecessary recommendations.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

print("Number of content records:", len(df))

print("\nTrend direction:")
print(df["trend_direction"].value_counts())

print("\nAverage impressions:")
print("Previous 30 days:", round(df["impressions_prev_30d"].mean(), 2))
print("Latest 30 days:", round(df["impressions_last_30d"].mean(), 2))
# Out:
# Number of content records: 30000
#
# Trend direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average impressions:
# Previous 30 days: 1783.08
# Latest 30 days: 1429.06

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This project will be able to say that certain historical signals are useful for predicting or ranking the likelihood of future page movement within the time window I define. The output should be treated as decision-support that helps prioritize pages for human review. I can describe relationships and predictive performance based on the data and validation results, using careful terms such as "observed", "measured", "associated with", and "predicted".

# However, the project will not prove that a particular content change causes a page to recover, and it will not prove that a specific signal is a direct ranking factor used by Google. A prediction will also not mean that the predicted outcome is guaranteed to happen. In addition, I will not claim that the model can predict Google's algorithm itself. These limitations are important because the dataset is observational and because future prediction must be separated carefully from causal conclusions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
